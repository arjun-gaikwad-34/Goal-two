# %%
import numpy as np
import pandas as pd
import cv2
import PIL
import pytesseract
from glob import glob
import spacy
import matplotlib.pyplot as plt
import re
import string

# %%
def cleanText(txt):
    whitespace = string.whitespace
    punctuation = "!#$%&'()*+:;<=>?[\\]^`{|}~"
    tableWhitespace = str.maketrans("", "", whitespace)
    tablePunctuation = str.maketrans("", "", punctuation)
    text = str(txt)
    text = text.lower()
    removewhitespace = text.translate(tableWhitespace)
    removepunctuation = removewhitespace.translate(tablePunctuation)
    return str(removepunctuation)

# %%
# Load NER model
model_ner=spacy.load('output/model-last')

# %%
# Load Image
image = cv2.imread('demo.png')
# To show image
cv2.imshow('demo',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Extract data using pytesseract
tessData=pytesseract.image_to_data(image)
# Convert data into dataframe
tessList = list(map(lambda x: x.split('\t'), tessData.split('\n')))
df = pd.DataFrame(tessList[1:], columns=tessList[0])
df.dropna(inplace=True) # drop missing values
df['text']=df['text'].apply(cleanText)

# Convert data into content
df_clean = df.query('text != "" ') # take only clean text that is not empty
content = " ".join([w for w in df_clean['text']])


# Get predictions from NER model

doc = model_ner(content)

# %%
# To visualize using spacy displacy
from spacy import displacy

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ©
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PHONE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     91-8830952270
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
# ° adv. ahilya nalawade b.a. ll.b. hons. _ maharashtra
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     national
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     law
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  university aurangabad &quot; the boh kk za 2 so ged 0 es sk gs © es a ae eae a es ess se sl &quot; ‘meera bhakti’ apartment, shop no.8, ‘c’ wing, behind d mart mall, be rankala, kolhapur.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adv.ahilyanalawade07@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
# </div></span>

# %%
docjson = doc.to_json()
docjson.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
docjson['tokens']
# Out:
# [{'id': 0, 'start': 0, 'end': 1},
#  {'id': 1, 'start': 2, 'end': 4},
#  {'id': 2, 'start': 4, 'end': 5},
#  {'id': 3, 'start': 5, 'end': 15},
#  {'id': 4, 'start': 15, 'end': 16},
#  {'id': 5, 'start': 17, 'end': 20},
#  {'id': 6, 'start': 20, 'end': 21},
#  {'id': 7, 'start': 22, 'end': 28},
#  {'id': 8, 'start': 29, 'end': 37},
#  {'id': 9, 'start': 38, 'end': 41},
#  {'id': 10, 'start': 41, 'end': 42},
#  {'id': 11, 'start': 43, 'end': 47},
#  {'id': 12, 'start': 47, 'end': 48},
#  {'id': 13, 'start': 49, 'end': 53},
#  {'id': 14, 'start': 53, 'end': 54},
#  {'id': 15, 'start': 55, 'end': 56},
#  {'id': 16, 'start': 57, 'end': 68},
#  {'id': 17, 'start': 69, 'end': 77},
#  {'id': 18, 'start': 78, 'end': 81},
#  {'id': 19, 'start': 82, 'end': 92},
#  {'id': 20, 'start': 93, 'end': 103},
#  {'id': 21, 'start': 104, 'end': 105},
#  {'id': 22, 'start': 106, 'end': 109},
#  {'id': 23, 'start': 110, 'end': 113},
#  {'id': 24, 'start': 114, 'end': 116},
#  {'id': 25, 'start': 117, 'end': 119},
#  {'id': 26, 'start': 120, 'end': 121},
#  {'id': 27, 'start': 122, 'end': 124},
#  {'id': 28, 'start': 125, 'end': 128},
#  {'id': 29, 'start': 129, 'end': 130},
#  {'id': 30, 'start': 131, 'end': 133},
#  {'id': 31, 'start': 134, 'end': 136},
#  {'id': 32, 'start': 137, 'end': 139},
#  {'id': 33, 'start': 140, 'end': 141},
#  {'id': 34, 'start': 142, 'end': 144},
#  {'id': 35, 'start': 145, 'end': 146},
#  {'id': 36, 'start': 147, 'end': 149},
#  {'id': 37, 'start': 150, 'end': 153},
#  {'id': 38, 'start': 154, 'end': 155},
#  {'id': 39, 'start': 156, 'end': 158},
#  {'id': 40, 'start': 159, 'end': 162},
#  {'id': 41, 'start': 163, 'end': 165},
#  {'id': 42, 'start': 166, 'end': 168},
#  {'id': 43, 'start': 169, 'end': 170},
#  {'id': 44, 'start': 171, 'end': 172},
#  {'id': 45, 'start': 172, 'end': 177},
#  {'id': 46, 'start': 178, 'end': 184},
#  {'id': 47, 'start': 184, 'end': 185},
#  {'id': 48, 'start': 186, 'end': 195},
#  {'id': 49, 'start': 195, 'end': 196},
#  {'id': 50, 'start': 197, 'end': 201},
#  {'id': 51, 'start': 202, 'end': 206},
#  {'id': 52, 'start': 206, 'end': 207},
#  {'id': 53, 'start': 208, 'end': 209},
#  {'id': 54, 'start': 209, 'end': 210},
#  {'id': 55, 'start': 210, 'end': 211},
#  {'id': 56, 'start': 212, 'end': 216},
#  {'id': 57, 'start': 216, 'end': 217},
#  {'id': 58, 'start': 218, 'end': 224},
#  {'id': 59, 'start': 225, 'end': 226},
#  {'id': 60, 'start': 227, 'end': 231},
#  {'id': 61, 'start': 232, 'end': 236},
#  {'id': 62, 'start': 236, 'end': 237},
#  {'id': 63, 'start': 238, 'end': 240},
#  {'id': 64, 'start': 241, 'end': 248},
#  {'id': 65, 'start': 248, 'end': 249},
#  {'id': 66, 'start': 250, 'end': 258},
#  {'id': 67, 'start': 258, 'end': 259},
#  {'id': 68, 'start': 260, 'end': 290}]

# %%
doc_text = docjson['text']
dataframe_tokens = pd.DataFrame(docjson['tokens'])
dataframe_tokens.head()
# Out:
#    id  start  end
# 0   0      0    1
# 1   1      2    4
# 2   2      4    5
# 3   3      5   15
# 4   4     15   16

# %%
dataframe_tokens['token'] = dataframe_tokens[['start','end']].apply(lambda x:doc_text[x[0]:x[1]], axis=1)
dataframe_tokens.head(20)
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\557297699.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataframe_tokens['token'] = dataframe_tokens[['start','end']].apply(lambda x:doc_text[x[0]:x[1]], axis=1)
#     id  start  end        token
# 0    0      0    1            ©
# 1    1      2    4           91
# 2    2      4    5            -
# 3    3      5   15   8830952270
# 4    4     15   16            °
# 5    5     17   20          adv
# 6    6     20   21            .
# 7    7     22   28       ahilya
# 8    8     29   37     nalawade
# 9    9     38   41          b.a
# 10  10     41   42            .
# 11  11     43   47         ll.b
# 12  12     47   48            .
# 13  13     49   53         hons
# 14  14     53   54            .
# 15  15     55   56            _
# 16  16     57   68  maharashtra
# 17  17     69   77     national
# 18  18     78   81          law
# 19  19     82   92   university

# %%
pd.DataFrame(docjson['ents'])[['start','label']]
# Out:
#    start    label
# 0      0  I-PHONE
# 1      2  B-PHONE
# 2     69    B-ORG
# 3     78    I-ORG
# 4    260  B-EMAIL

# %%
right_table = pd.DataFrame(docjson['ents'])[['start','label']]
right_table
# Out:
#    start    label
# 0      0  I-PHONE
# 1      2  B-PHONE
# 2     69    B-ORG
# 3     78    I-ORG
# 4    260  B-EMAIL

# %%
dataframe_tokens = pd.merge(dataframe_tokens, right_table, how='left', on='start')

# %%
dataframe_tokens
# Out:
#     id  start  end                           token    label
# 0    0      0    1                               ©  I-PHONE
# 1    1      2    4                              91  B-PHONE
# 2    2      4    5                               -      NaN
# 3    3      5   15                      8830952270      NaN
# 4    4     15   16                               °      NaN
# ..  ..    ...  ...                             ...      ...
# 64  64    241  248                         rankala      NaN
# 65  65    248  249                               ,      NaN
# 66  66    250  258                        kolhapur      NaN
# 67  67    258  259                               .      NaN
# 68  68    260  290  adv.ahilyanalawade07@gmail.com  B-EMAIL
#
# [69 rows x 5 columns]

# %%
dataframe_tokens.fillna('O', inplace=True)

# %%
dataframe_tokens.head(10)
# Out:
#    id  start  end       token    label
# 0   0      0    1           ©  I-PHONE
# 1   1      2    4          91  B-PHONE
# 2   2      4    5           -        O
# 3   3      5   15  8830952270        O
# 4   4     15   16           °        O
# 5   5     17   20         adv        O
# 6   6     20   21           .        O
# 7   7     22   28      ahilya        O
# 8   8     29   37    nalawade        O
# 9   9     38   41         b.a        O

# %% [markdown]
# For drawing the bounding box we need left, right, top and confidence score of the bounding box info from df_clean

# %%
# ASSUMING THAT EACH WORD IS SEPARATED BY ONE SPACE
df_clean.head(5)
df_clean['end'] = df_clean['text'].apply(lambda x: len(x) + 1).cumsum() - 1
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\754859177.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x) + 1).cumsum() - 1

# %%
df_clean.head(10)
# Out:
#    level page_num block_num par_num line_num word_num  left  top width height  \
# 8      5        1         2       1        1        1  1513   38    95    110
# 9      5        1         2       1        1        2  1655   55   810     98
# 13     5        1         3       1        1        1   731  384   261    106
# 14     5        1         3       1        1        2  1037  388   469    104
# 15     5        1         3       1        1        3  1553  391   739    105
# 17     5        1         3       1        2        1  1251  573   373    134
# 18     5        1         3       1        2        2  1667  574   252     86
# 19     5        1         3       1        2        3  1956  572   335    114
# 23     5        1         4       1        1        1   376  819     2      3
# 24     5        1         4       1        1        2   466  823   467    105
#
#          conf            text  end
# 8    0.862961               ©    1
# 9   74.315201  91-8830952270°   16
# 13  92.558205            adv.   21
# 14  91.801567          ahilya   28
# 15  90.126564        nalawade   37
# 17   6.284714            b.a.   42
# 18   6.284714           ll.b.   48
# 19  89.698112           hons.   54
# 23  74.782715               _   56
# 24  96.897415     maharashtra   68

# %%
df_clean["start"] = df_clean[["text", "end"]].apply(lambda x: x[1] - len(x[0]), axis=1)
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\1777414969.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_clean["start"] = df_clean[["text", "end"]].apply(lambda x: x[1] - len(x[0]), axis=1)
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\1777414969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["start"] = df_clean[["text", "end"]].apply(lambda x: x[1] - len(x[0]), axis=1)

# %%
df_clean.head(10)
# Out:
#    level page_num block_num par_num line_num word_num  left  top width height  \
# 8      5        1         2       1        1        1  1513   38    95    110
# 9      5        1         2       1        1        2  1655   55   810     98
# 13     5        1         3       1        1        1   731  384   261    106
# 14     5        1         3       1        1        2  1037  388   469    104
# 15     5        1         3       1        1        3  1553  391   739    105
# 17     5        1         3       1        2        1  1251  573   373    134
# 18     5        1         3       1        2        2  1667  574   252     86
# 19     5        1         3       1        2        3  1956  572   335    114
# 23     5        1         4       1        1        1   376  819     2      3
# 24     5        1         4       1        1        2   466  823   467    105
#
#          conf            text  end  start
# 8    0.862961               ©    1      0
# 9   74.315201  91-8830952270°   16      2
# 13  92.558205            adv.   21     17
# 14  91.801567          ahilya   28     22
# 15  90.126564        nalawade   37     29
# 17   6.284714            b.a.   42     38
# 18   6.284714           ll.b.   48     43
# 19  89.698112           hons.   54     49
# 23  74.782715               _   56     55
# 24  96.897415     maharashtra   68     57

# %%
# inner join with start as the common column for join
dataframe_info = pd.merge(df_clean, dataframe_tokens[['start','token','label']], how='inner', on='start')

# %%
dataframe_info.tail(10)
# Out:
#    level page_num block_num par_num line_num word_num  left   top width  \
# 42     5        1         6       1        1        7  1438  1101    78
# 43     5        1         6       1        1        8  1544  1103   185
# 44     5        1         6       1        1        9  1761  1107   230
# 45     5        1         6       1        1       10  2020  1110    49
# 46     5        1         6       1        1       11  2096  1111   150
# 47     5        1         6       1        1       12  2270  1114   154
# 48     5        1         6       1        2        1     2  1185   133
# 49     5        1         6       1        2        2   972  1189   282
# 50     5        1         6       1        2        3  1286  1193   310
# 51     5        1         7       1        1        1   732  1295  1276
#
#    height       conf                            text  end  start  \
# 42     62  88.115845                             ‘c’  211    208
# 43     79  96.983780                           wing,  217    212
# 44     64  93.305153                          behind  224    218
# 45     60  93.122993                               d  226    225
# 46     63  96.961861                            mart  231    227
# 47     70  74.981071                           mall,  237    232
# 48     64  21.179123                              be  240    238
# 49     74  92.606560                        rankala,  249    241
# 50     78  95.528534                       kolhapur.  259    250
# 51    122  72.984489  adv.ahilyanalawade07@gmail.com  290    260
#
#                              token    label
# 42                               ‘        O
# 43                            wing        O
# 44                          behind        O
# 45                               d        O
# 46                            mart        O
# 47                            mall        O
# 48                              be        O
# 49                         rankala        O
# 50                        kolhapur        O
# 51  adv.ahilyanalawade07@gmail.com  B-EMAIL

# %% [markdown]
# Bounding Box

# %%
bb_df = dataframe_info.query(' label != "O"')
img = image.copy()

for x, y, w, h, label in bb_df[["left", "top", "width", "height", "label"]].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)

    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(img, str(label), (x, y), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255), 2)

cv2.imshow("Predictions", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Combined bounding box
bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\2611818311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])

# %%
bb_df.head(10)
# Out:
#    level page_num block_num par_num line_num word_num  left   top width  \
# 0      5        1         2       1        1        1  1513    38    95
# 1      5        1         2       1        1        2  1655    55   810
# 10     5        1         4       1        1        3   963   827   300
# 11     5        1         4       1        1        4  1295   830   147
# 51     5        1         7       1        1        1   732  1295  1276
#
#    height       conf                            text  end  start  \
# 0     110   0.862961                               ©    1      0
# 1      98  74.315201                  91-8830952270°   16      2
# 10     84  96.493385                        national   77     69
# 11     74  96.818825                             law   81     78
# 51    122  72.984489  adv.ahilyanalawade07@gmail.com  290    260
#
#                              token  label
# 0                                ©  PHONE
# 1                               91  PHONE
# 10                        national    ORG
# 11                             law    ORG
# 51  adv.ahilyanalawade07@gmail.com  EMAIL

# %%
# Grouping the labels of one type eg: PHONE
class groupgen():
    def __init__(self):
        self.id=0
        self.text=''

    def getgroup(self,text):
        if self.text == text:
            return self.id
        else:
            self.id += 1
            self.text=text
            return self.id

# %%
grp_gen = groupgen()

# %%
bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\472836701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)

# %%
bb_df.head(10)
# Out:
#    level page_num block_num par_num line_num word_num  left   top width  \
# 0      5        1         2       1        1        1  1513    38    95
# 1      5        1         2       1        1        2  1655    55   810
# 10     5        1         4       1        1        3   963   827   300
# 11     5        1         4       1        1        4  1295   830   147
# 51     5        1         7       1        1        1   732  1295  1276
#
#    height       conf                            text  end  start  \
# 0     110   0.862961                               ©    1      0
# 1      98  74.315201                  91-8830952270°   16      2
# 10     84  96.493385                        national   77     69
# 11     74  96.818825                             law   81     78
# 51    122  72.984489  adv.ahilyanalawade07@gmail.com  290    260
#
#                              token  label  group
# 0                                ©  PHONE      1
# 1                               91  PHONE      1
# 10                        national    ORG      2
# 11                             law    ORG      2
# 51  adv.ahilyanalawade07@gmail.com  EMAIL      3

# %%
# Creating right and bottom of bounding box
bb_df[['left','width','top','height']] = bb_df[['left','width','top','height']].astype(int)
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\2055952346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left','width','top','height']] = bb_df[['left','width','top','height']].astype(int)

# %%
bb_df['right'] = bb_df['left'] + bb_df['width']
bb_df['bottom'] = bb_df['top'] + bb_df['height']
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\2787869466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\2787869466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
# tagging: groupby group
col_group = ['left','top','right','bottom','label','token','group']
group_tag_img = bb_df[col_group].groupby(by='group')

# %%
group_tag_img

# %%
img_tagging = group_tag_img.agg({
    'left':min,
    'right':max,
    'top':min,
    'bottom':max,
    'label':np.unique,
    'token': lambda x: " ".join(x)

})
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\3723226414.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   img_tagging = group_tag_img.agg({
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\3723226414.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   img_tagging = group_tag_img.agg({

# %%
img_tagging
# Out:
#        left  right   top  bottom    label                           token
# group
# 1      1513   2465    38     153  [PHONE]                            © 91
# 2       963   1442   827     911    [ORG]                    national law
# 3       732   2008  1295    1417  [EMAIL]  adv.ahilyanalawade07@gmail.com

# %%
img_bb = image.copy()
for l, r, t, b, label, token in img_tagging.values:
    cv2.rectangle(img_bb, (l, t), (r, b), (0, 255, 0), 2)

    cv2.putText(
        img_bb, str(label[0]), (l, t), cv2.FONT_HERSHEY_PLAIN, 2, (255, 0, 255), 2
    )

# Define the window name
window_name = "Bounding Box Business Card"

# Set the window properties
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)

# Resize the window
cv2.resizeWindow(window_name, 900, 600)  # Adjust the dimensions as needed

# Display the image
cv2.imshow(window_name, img_bb)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Parsing Function

# %%
def parser(text, label):
    if label == "PHONE":
        text = text.lower()
        text = re.sub(r"\D", "", text)

    elif label == "EMAIL":
        text = text.lower()
        allow_special_char = r"@-_."
        text = re.sub(r"[^A-Za-z0-9{} ]".format(allow_special_char), "", text)

    elif label == "WEB":
        text = text.lower()
        allow_special_char = r":/.%#-"
        text = re.sub(r"[^A-Za-z0-9{} -]".format(allow_special_char), "", text)

    elif label in ("NAME", "DES"):
        text = text.lower()
        text = re.sub(r"[^a-z ]", "", text)
        text = text.title()

    elif label == "ORG":
        text = text.lower()
        text = re.sub(r"[^a-z0-9 ]", "", text)
        text = text.title()

    return text

# %%
parser(r"arjun\@gmail.com", "EMAIL")
# Out:
# 'arjun\\@gmail.com'

# %% [markdown]
# Entities

# %%
info_array = dataframe_info[["token", "label"]].values
entities = dict(NAME=[], ORG=[], DES=[], PHONE=[], WEB=[], EMAIL=[])
previous = "O"

for token, label in info_array:
    bio_tag = label[:1]
    label_tag = label[2:]

    # step 1 parse the token
    text = parser(token, label_tag)

    if bio_tag in ("B", "I"):

        if previous != label_tag:
            entities[label_tag].append(text)

        else:
            if bio_tag == "B":
                entities[label_tag].append(text)

            else:
                if label_tag in ("NAME", "ORG", "DES"):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + text

    previous = label_tag
# Out:
# C:\Users\AGaikwad\AppData\Local\Temp\ipykernel_28708\1009433710.py:8: SyntaxWarning: invalid escape sequence '\.'
#   allow_special_char = '@-_\.'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[116], line 10
#       7 label_tag = label[2:]
#       9 # step 1 parse the token
# ---> 10 text = parser(token, label_tag)
#      12 if bio_tag in ("B", "I"):
#      14     if previous != label_tag:
#
# Cell In[114], line 14, in parser(text, label)
#      12     text = text.lower()
#      13     allow_special_char=':/.%#-'
# ---> 14     text = re.sub(r'[^A-Za-z0-9{} -]'.format(allow_special_char),'',text)
#      16 elif label in ('NAME','DES'):
#      17     text = text.lower()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:186, in sub(pattern, repl, string, count, flags)
#     179 def sub(pattern, repl, string, count=0, flags=0):
#     180     """Return the string obtained by replacing the leftmost
#     181     non-overlapping occurrences of the pattern in string by the
#     182     replacement repl.  repl can be either a string or a callable;
#     183     if a string, backslash escapes in it are processed.  If it is
#     184     a callable, it's passed the Match object and must return
#     185     a replacement string to be used."""
# --> 186     return _compile(pattern, flags).sub(repl, string, count)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\_parser.py:979, in parse(str, flags, state)
#     976 state.flags = flags
#     977 state.str = str
# --> 979 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     980 p.state.flags = fix_flags(str, p.state.flags)
#     982 if source.next is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\_parser.py:460, in _parse_sub(source, state, verbose, nested)
#     458 start = source.tell()
#     459 while True:
# --> 460     itemsappend(_parse(source, state, verbose, nested + 1,
#     461                        not nested and not items))
#     462     if not sourcematch("|"):
#     463         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\_parser.py:617, in _parse(source, state, verbose, nested, first)
#     615     if hi < lo:
#     616         msg = "bad character range %s-%s" % (this, that)
# --> 617         raise source.error(msg, len(this) + 1 + len(that))
#     618     setappend((RANGE, (lo, hi)))
#     619 else:
#
# error: bad character range #-  at position 15
